# %%
install.packages("pacman", repos="https://cran.rstudio.com/", dependencies = FALSE, Ncpus = 4)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Header ----------------------------------------------------------------------------------------------------------
#' atcd.R
#' ---
#' Scrapes the ATC data from https://www.whocc.no/atc_ddd_index/.
#'
#' By Fabrício Kury
#' File started on 2020/3/20 5:08.
#' Margin column at 120 characters.
#'
##
# Globals ---------------------------------------------------------------------------------------------------------
pacman::p_load(rvest)
pacman::p_load(dplyr)
pacman::p_load(readr)
pacman::p_load(xml2)

ensure_directory <- function(...) {
  dir_path <- paste0(...)
  if(!dir.exists(dir_path))
    dir.create(dir_path, recursive = TRUE)
  dir_path
}

out_dir <- ensure_directory('output')
rds_dir <- ensure_directory(out_dir, '/rds')


options(expressions = 100000) # Allow deep recursion.

wrapRDS <- function(var, exprs, by_name = FALSE, pass_val = FALSE, assign_val = TRUE) {
  #' This is a handy function to store variables between runs of the code and skip recreating them.
  #' It checks if an RDS file for var already exists in rds_dir. If it does, read it from there. If
  #' it does not, evaluates exprs and saves it to such RDS file.
  #' var: The object itself, unquoted, or a character vector containing its name.
  #' exprs: Expression to be evaluated if the RDS file doesn't already exist.
  #' by_name: If true, var is interpreted as a character vector with the object name.
  #' pass_val: If true, will return the object at the end.
  #' assign_val: If true, will assign the value of the object to its name in the calling envirmt.
  if(by_name)
    varname <- var
  else
    varname <- deparse(substitute(var))

  if(exists(varname, envir = parent.frame(n = 1)))
    message("Object '", varname, "' already exists.")
  else {
    rds_file <- paste0(rds_dir, '/', varname, '.rds')
    if(file.exists(rds_file)) {
      message("Reading '", varname, "' from file '", rds_file, "'... ")
      var_val <- readRDS(rds_file)
    } else {
      # Evaluate the expression in a temporary environment, akin to a function call.
      # TODO: Revise if I need to create a new environment using new.env(). Is this function's own environment enough?
      message('Building ', varname, '.')
      var_val <- eval(substitute(exprs),
        envir = new.env(parent = parent.frame(n = 1)))
      message(varname, " completed. Saving to file '", rds_file, "'... ")
      if(!dir.exists(rds_dir))
        dir.create(rds_dir, recursive = T)
      saveRDS(var_val, rds_file)
    }
    if(assign_val)
      assign(varname, var_val, envir = parent.frame(n = 1))
  }

  if(pass_val || !assign_val)
    var_val
}

getRDS <- function(var, by_name = FALSE, pass_val = FALSE, assign_val = TRUE) {
  #' In connection to wrapRDS, this function only loads the RDS file, or raises an error if unable to.
  #' var: The object itself, unquoted, or a character vector containing its name.
  #' by_name: If true, var is interpreted as a character vector with the object name.
  #' pass_val: If true, will return the object at the end.
  #' assign_val: If true, will assign the value of the object to its name in the calling envirmt.
  if(by_name)
    varname <- var
  else
    varname <- deparse(substitute(var))

  if(exists(varname, envir = parent.frame(n = 1))) {
    message("Object '", varname, "' already exists.")
    var_val <- get(varname, envir = parent.frame(n = 1))
  } else {
    rds_file <- paste0(rds_dir, '/', varname, '.rds')
    if(file.exists(rds_file)) {
      message("Reading '", varname, "' from file '", rds_file, "'... ")
      var_val <- readRDS(rds_file)
    } else {
      stop(paste0('Unable to find file ', rds_file, '.'))
    }

    if(assign_val)
      assign(varname, var_val, envir = parent.frame(n = 1))
  }

  if(pass_val || !assign_val)
    var_val
}

# The script will retrieve all ATC roots in atc_roots. Remember that for each root all subcodes will be retrieved.
# A 	Alimentary tract and metabolism
# B 	Blood and blood forming organs
# C 	Cardiovascular system
# D 	Dermatologicals
# G 	Genito-urinary system and sex hormones
# H 	Systemic hormonal preparations, excluding sex hormones and insulins
# J 	Antiinfectives for systemic use
# L 	Antineoplastic and immunomodulating agents
# M 	Musculo-skeletal system
# N 	Nervous system
# P 	Antiparasitic products, insecticides and repellents
# R 	Respiratory system
# S 	Sensory organs
# V 	Various
atc_roots <- c('A', 'B', 'C', 'D', 'G', 'H', 'J', 'L', 'M', 'N', 'P', 'R', 'S', 'V')


# Scrape data -----------------------------------------------------------------------------------------------------
scrape_who_atc <- function(root_atc_code) {
  # This function scrapes and returns a tibble with all data available from https://www.whocc.no/atc_ddd_index/ for the
  # given ATC code and all its subcodes.
  if(length(root_atc_code) != 1)
    stop('scrape_who_atc() only accepts single objects, not vectors. Please provide a single valid ATC code as input.')

  web_address <- paste0('https://www.whocc.no/atc_ddd_index/?code=', root_atc_code, '&showdescription=no')
  message('Scraping ', web_address, '.')
  atc_code_length <- nchar(root_atc_code)
  html_data <- read_html(web_address)

  if(atc_code_length < 5) {
    scraped_strings <- html_data |>
      html_node(css="#content > p:nth-of-type(2n)") |>
      html_text() |>
      strsplit('\n') |>
      nth(1) |>
      Filter(f = nchar)

    if(length(scraped_strings) == 0)
      return(NULL)

    tval <- lapply(scraped_strings, function(scraped_string) {
      atc_codes <- sub('^([A-Z]\\S*) (.*)', '\\1', scraped_string)
      atc_names <- sub('^([A-Z]\\S*) (.*)', '\\2', scraped_string)
      t1 <- tibble(atc_code = atc_codes, atc_name = atc_names)
      t2 <- lapply(atc_codes, scrape_who_atc) |> bind_rows()
      bind_rows(t1, t2)
    }) |>
      bind_rows()

    # Add the root node if needed.
    if(atc_code_length == 1) {
      root_atc_code_name <- html_data |>
        html_nodes(css="#content a")

      root_atc_code_name <- root_atc_code_name[3]

      root_atc_code_name <- html_text(root_atc_code_name)

      return(bind_rows(tibble(atc_code = root_atc_code, atc_name = root_atc_code_name), tval))
    } else return(tval)
  } else {
    proc_sdt <- function(sdt) {
      if(class(sdt) == 'xml_missing')
        return(NULL)

      retval <- sdt |>
        html_table(header = TRUE) |>
        rename(atc_code = `ATC code`, atc_name = Name, ddd = DDD, uom = U, adm_r = `Adm.R`, note = Note) |>
        mutate_all(~ifelse(.=='', NA, .))

      # The table on the website does not repeat atc_code and atc_name in subsequent rows when that ATC code has more
      # than one ddd/uom/adm_r. Let's fill-in the blanks when that is the case.
      if(nrow(retval) > 1)
        for(i in 2:nrow(retval))
          if(is.na(retval$atc_code[i])) {
            retval$atc_code[i] <- retval$atc_code[i-1]
            retval$atc_name[i] <- retval$atc_name[i-1]
          }

      return(retval)
    }

    retval <- html_node(html_data, xpath="//ul/table") |>
      proc_sdt()

    return(retval)
  }
}

# Request all codes and subcodes within atc_roots.
for(atc_root in atc_roots)
  paste0('who_atc_', atc_root) |>
  wrapRDS(by_name = TRUE, scrape_who_atc(atc_root))


# Write results to storage ----------------------------------------------------------------------------------------
# Read the files produced by scrape_who_atc().
who_atc <- paste0('who_atc_', atc_roots) |>
  lapply(getRDS, by_name = TRUE, assign_val = FALSE, pass_val = TRUE) |>
  bind_rows()

# Write them to a CSV file. Generate file name from current date in year-month-day format.
out_file_name <- paste0(out_dir, '/WHO ATC-DDD ', format(Sys.Date(), "%Y-%m-%d"), '.csv')
message('Writing results to ', out_file_name, '.')
if(file.exists(out_file_name))
  message('Warning: file already exists. Will be overwritten.')
write_csv(who_atc, out_file_name)


# Finish execution ------------------------------------------------------------------------------------------------
message('Script execution completed.')
# Out:
# Building who_atc_A.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A01AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A01AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A01AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A02X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03DC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03ED&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A03FA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A04&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A04A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A04AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A04AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A05C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A06AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07EC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07FA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A07XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A08&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A08A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A08AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A08AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A08AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A09&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A09A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A09AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A09AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A09AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BJ&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A10XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11EC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11ED&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11EX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11G&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11GA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11GB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11H&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11HA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11J&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11JA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11JB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A11JC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12CD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12CE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A12CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A13&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A13A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A14&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A14A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A14AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A14AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A14B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A15&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A16&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A16A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A16AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A16AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=A16AX&showdescription=no.
#
# who_atc_A completed. Saving to file 'output/rds/who_atc_A.rds'...
#
# Building who_atc_B.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B01AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B02BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B03XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05XB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05XC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05Z&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05ZA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B05ZB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B06&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B06A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B06AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B06AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B06AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=B06AX&showdescription=no.
#
# who_atc_B completed. Saving to file 'output/rds/who_atc_B.rds'...
#
# Building who_atc_C.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01BG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01CE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01DX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C01EX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02DC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02DD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02DG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02K&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02KA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02KB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02KC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02KD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02KN&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02KX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02L&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LL&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LN&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02LX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C02N&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03AH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03BK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03CD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C03XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C04AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C05XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07AG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07BG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07CG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07FB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C07FX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08EX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08G&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C08GA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09DX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C09XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=C10BX&showdescription=no.
#
# who_atc_C completed. Saving to file 'output/rds/who_atc_C.rds'...
#
# Building who_atc_D.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D01BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D02BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D03AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D03AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D03B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D03BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D04&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D04A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D04AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D04AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D04AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D05BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D06C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07CD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07XB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07XC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D07XD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AJ&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AL&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D08AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D09&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D09A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D09AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D09AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D09AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D10BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11AH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=D11AX&showdescription=no.
#
# who_atc_D completed. Saving to file 'output/rds/who_atc_D.rds'...
#
# Building who_atc_G.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01BE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G01BF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G02CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03DC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03EK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03FA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03FB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03G&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03GA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03GB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03H&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03HA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03HB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03XB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03XC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G03XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04BD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04BE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=G04CX&showdescription=no.
#
# who_atc_G completed. Saving to file 'output/rds/who_atc_G.rds'...
#
# Building who_atc_H.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H01CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=H02CA&showdescription=no.
#
# ...
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R05DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R05F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R05FA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R05FB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R05X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R06AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R07&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R07A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R07AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R07AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=R07AX&showdescription=no.
#
# who_atc_R completed. Saving to file 'output/rds/who_atc_R.rds'...
#
# Building who_atc_S.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01BB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01BC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01EC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01ED&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01EE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01EX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01FA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01FB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01G&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01GA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01GX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01H&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01HA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01J&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01JA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01JX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01K&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01KA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01KX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01L&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01LA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S01XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S02DC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=S03D&showdescription=no.
#
# who_atc_S completed. Saving to file 'output/rds/who_atc_S.rds'...
#
# Building who_atc_V.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V01&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V01A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V01AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AM&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AN&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V03AZ&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CG&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CH&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CJ&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CK&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CL&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CM&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V04CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DE&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DF&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V06DX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AN&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AR&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AS&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AT&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AV&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AY&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V07AZ&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08AC&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08AD&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08CB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V08DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09AB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09BA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09C&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09CA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09CX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09D&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09DA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09DB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09DX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09E&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09EA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09EB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09EX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09F&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09FX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09G&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09GA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09GB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09GX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09H&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09HA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09HB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09HX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09I&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09IA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09IB&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09IX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V09XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10A&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10AA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10AX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10B&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10BX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10X&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10XA&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V10XX&showdescription=no.
#
# Scraping https://www.whocc.no/atc_ddd_index/?code=V20&showdescription=no.
#
# who_atc_V completed. Saving to file 'output/rds/who_atc_V.rds'...
#
# Object 'who_atc_A' already exists.
#
# Object 'who_atc_B' already exists.
#
# Object 'who_atc_C' already exists.
#
# Object 'who_atc_D' already exists.
#
# Object 'who_atc_G' already exists.
#
# Object 'who_atc_H' already exists.
#
# Object 'who_atc_J' already exists.
#
# Object 'who_atc_L' already exists.
#
# Object 'who_atc_M' already exists.
#
# Object 'who_atc_N' already exists.
#
# Object 'who_atc_P' already exists.
#
# Object 'who_atc_R' already exists.
#
# Object 'who_atc_S' already exists.
#
# Object 'who_atc_V' already exists.
#
# Writing results to output/WHO ATC-DDD 2025-06-14.csv.
#
# Script execution completed.
